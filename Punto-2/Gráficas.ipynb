# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = loadtxt("3cuerpos.dat")
plot(datos[:,0],datos[:,1])
plot(datos[:,3],datos[:,4])
plot(datos[:,6],datos[:,7])

# %%
plot(datos[:,9])
plot(datos[:,10])

# %%
plot(datos[:,9]-datos[:,10])

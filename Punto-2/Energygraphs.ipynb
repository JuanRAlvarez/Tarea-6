# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = loadtxt("3cuerpos.dat")

# %%
plot(datos[:,12])

# %%
plot(datos[:,13])

# %%
plot(datos[:,0],datos[:,1])
plot(datos[:,2],datos[:,3])
plot(datos[:,4],datos[:,5])

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = np.loadtxt("3cuerpos.dat")
plot(datos[:,0],datos[:,1],c='r')
plot(datos[:,2],datos[:,3],c='g')
plot(datos[:,4],datos[:,5],c='b')
#plot(datos[:,6],datos[:,7],c='k')
#plot(datos[:,8],datos[:,9],c='c')
#plot(datos[:,10],datos[:,11],c='m')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = np.loadtxt("IC.dat")
daticos = np.loadtxt("3cuerpos.dat")

# %%
N = np.shape(datos)[0]

for i in range(N):
    if (datos[i,0] == -1):
        scatter(datos[i,1],datos[i,2],c='r')
    else:
        scatter(datos[i,1],datos[i,2],c='g')

# %%
m = np.shape(daticos)[0]

for i in range(m):
    if (datos[i,0] == -1):
        scatter(daticos[i,1],daticos[i,2],c='r')
    else:
        scatter(daticos[i,1],daticos[i,2],c='g')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datos = np.loadtxt("IC.dat")
daticos1 = np.loadtxt("1.dat")
daticos2 = np.loadtxt("2.dat")
daticos3 = np.loadtxt("3.dat")
daticos4 = np.loadtxt("4.dat")
daticos5 = np.loadtxt("5.dat")

# %%
N = np.shape(datos)[0]

for i in range(N):
    if (datos[i,0] == -1):
        scatter(datos[i,1],datos[i,2],c='r')
    else:
        scatter(datos[i,1],datos[i,2],c='g')
   
m1 = np.shape(daticos1)[0]

for i in range(m1):
    if (datos[i,0] == -1):
        scatter(daticos1[i,1],daticos1[i,2],c='r')
    else:
        scatter(daticos1[i,1],daticos1[i,2],c='g')        
        
m2 = np.shape(daticos2)[0]

for i in range(m2):
    if (datos[i,0] == -1):
        scatter(daticos2[i,1],daticos2[i,2],c='r')
    else:
        scatter(daticos2[i,1],daticos2[i,2],c='g')
        
m3 = np.shape(daticos3)[0]

for i in range(m1):
    if (datos[i,0] == -1):
        scatter(daticos3[i,1],daticos3[i,2],c='r')
    else:
        scatter(daticos3[i,1],daticos3[i,2],c='g')        
        
m4 = np.shape(daticos4)[0]

for i in range(m4):
    if (datos[i,0] == -1):
        scatter(daticos4[i,1],daticos4[i,2],c='r')
    else:
        scatter(daticos4[i,1],daticos4[i,2],c='g')

# %%
m = np.shape(daticos1)[0]

for i in range(m):
    if (datos[i,0] == -1):
        scatter(daticos4[i,1],daticos4[i,2],c='r')
    else:
        scatter(daticos4[i,1],daticos4[i,2],c='g')
        
m = np.shape(daticos2)[0]

for i in range(m):
    if (datos[i,0] == -1):
        scatter(daticos5[i,1],daticos5[i,2],c='r')
    else:
        scatter(daticos5[i,1],daticos5[i,2],c='g')

# %%
datos = np.loadtxt("Conds.dat")

# %%
N = np.shape(datos)[0]

for i in range(N):
    if (datos[i,0] == -1):
        scatter(datos[i,1],datos[i,2],c='r')
    else:
        scatter(datos[i,1],datos[i,2],c='g')

# %%
daticos1 = np.loadtxt("1.dat")
daticos2 = np.loadtxt("2.dat")
daticos3 = np.loadtxt("3.dat")
daticos4 = np.loadtxt("4.dat")
daticos5 = np.loadtxt("5.dat")

# %%
m1 = np.shape(daticos1)[0]

for i in range(m1):
    if (datos[i,0] == -1):
        scatter(daticos5[i,1],daticos1[i,2],c='r')
    else:
        scatter(daticos5[i,1],daticos1[i,2],c='g')
